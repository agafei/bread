# %% [markdown]
# # Assignment: Libraries
#
# This problem set aims to develop your ability to use non-standard libraries such as NumPy, Pandas, Matplotlib, and requests.
#
# Please follow all instructions precisely.

# %% [markdown]
# ## Prerequisite: Install libraries
#
# To do this assignment, you need to have a few libraries installed. You already know how to install libraries in a basic Python virtual environment. In Anaconda, it is even easier.
#
# Install the following libraries:
# 1. Pandas
# 2. Requests
# 3. Matplotlib
#
# Follow this tutorial to install external libraries for your Jupyter notebook using the Anaconda Navigator.
#
# https://www.tutorialspoint.com/add-packages-to-anaconda-environment-in-python
#
# Once you are done, run the following cell. If it does nothing (i.e., if it throws no errors), then you may proceed.

# %%
# NON-EDITABLE CODE CELL
# You may run this cell, but do not edit it.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests

# %% [markdown]
# ## Note
#
# 1. There is a good chance that you will have to look up how to do things using these libraries. This is fine. Just credit your sources appropriately.

# %% [markdown]
# ## Problem 1: Association Rules

# %% [markdown]
# ### Context
#
# You are a data consultant for a medium-sized grocery. Your job is to help the grocery's marketing and sales team identify the most frequent purchases of customers.

# %% [markdown]
# ### 1.1
#
# Read the file `sample order basket.csv` into a Pandas DataFrame called `df`.

# %%
# CODE CELL

# CODE START

df=pd.read_csv('sample order basket.csv')


# CODE END

# %% [markdown]
# ### 1.2
#
# Create a "binary table" using a Pandas DataFrame. Save the DataFrame in a variable called `binary_table`.
#
# The specifications of the binary table are as follows:
# 1. The data in the binary table is based on the order log contained in `df`.
# 2. The index values of the binary table are the unique order IDs contained in the sales logs. These are arranged in ascending numerical order. Format the values as `int64`.
# 3. The column values of the binary table are the unique products contained in the sales logs. These are arranged in alphabetical order. Format the values as `object`.
# 4. The values of the binary table are either 0 or 1. A value will be 1 if the respective product is present in the respective order, and it will be 0 if the respective product is not present in the respective order. So, for example: if Order 5 ordered an apple, then the cell at row 5, column apple will have the value 1, and every other cell at row 5 will have the value 0.

# %%
# CODE CELL

# CODE START

binary_table=pd.DataFrame(df)

np.int64(binary_table['OrderNum'])
binary_table['Product']=binary_table['Product'].astype('object')
values=pd.get_dummies(binary_table['Product'])    
products=tuple(values)

for items in products:
    binary_table[items]=values[items]
final={'bread':'sum','cheese':'sum','eggs':'sum','flour':'sum','jam':'sum'}
binary_table=binary_table.groupby(binary_table['OrderNum']).aggregate(final)


# CODE END
binary_table
#references:
#https://stackoverflow.com/questions/32011359/convert-categorical-data-in-pandas-dataframe
#https://pandas.pydata.org/docs/reference/api/pandas.get_dummies.html
#https://datascience.stackexchange.com/questions/14847/multiple-categorical-values-for-a-single-feature-how-to-convert-them-to-binary-u
# Out:
#           bread  cheese  eggs  flour  jam
# OrderNum
# 1000          0       0     1      0    0
# 1001          1       0     0      0    0
# 1002          1       0     1      1    0
# 1003          1       0     1      0    1
# 1004          0       0     1      0    0
# ...         ...     ...   ...    ...  ...
# 1495          1       0     1      1    0
# 1496          1       1     1      0    0
# 1497          0       0     0      0    1
# 1498          1       0     0      0    0
# 1499          1       0     1      0    0
#
# [500 rows x 5 columns]

# %% [markdown]
# ### 1.3
#
# Using `binary_table`, create a report. Store this report in a Pandas DataFrame called `report`.
#
# The specifications of the report are as follows:
# 1. The data in the report is based on the data in `binary_table`.
# 2. The index values of `report` are simply the defaults (i.e., counting up from 0 to whatever number).
# 3. `report` has two columns: `combination` and `count`. The `combination` column will contain tuples that describe an order combination (e.g., ("apple", "eggplant")). Format the `combination` column as `object`. The `count` column will contain an integer value describing the number of times that this combination appeared in the list of orders. Format the `count` column as `int64`.
# 4. Sort `reports` by `count` in descending order. The order of combinations within each count bracket does not matter.
#
# You may use any standard library from Python 3.8 that you feel is necessary to complete this item. (This just means that you can use any standard Python library as long as it was in Python 3.8).

# %%
# CODE CELL

# CODE START

final_products=[]
for i in range(len(binary_table)):
    product=''
    for item in tuple(binary_table):
        if binary_table.iloc[i][item]==1:
            if product!='':
                product=product+', '+item
            else:
                product=product+item
        else:
            pass
    final_products.append({'combination':product,'count':1})
final_products=pd.DataFrame(final_products)  
combination={'count':'sum'}
report=final_products.groupby('combination').aggregate(combination)
reports=report.sort_values('count',ascending=False)


# CODE END
reports

#references
#https://stackoverflow.com/questions/35268817/unique-combinations-of-values-in-selected-columns-in-pandas-data-frame-and-count
#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iloc.html
#https://stackoverflow.com/questions/24988873/python-sort-descending-dataframe-with-pandas
# Out:
#                                  count
# combination
# bread                               65
# bread, jam                          57
# bread, eggs                         47
# bread, eggs, jam                    46
# eggs                                31
# jam                                 26
# bread, eggs, flour                  21
# bread, flour, jam                   18
# eggs, jam                           17
# bread, cheese, eggs                 17
# bread, cheese                       15
# bread, flour                        15
# cheese                              13
# bread, eggs, flour, jam             13
# bread, cheese, jam                  12
# eggs, flour, jam                    11
# bread, cheese, flour                 9
# flour                                9
# cheese, eggs, jam                    8
# cheese, jam                          7
# bread, cheese, eggs, jam             7
# cheese, eggs                         6
# cheese, eggs, flour, jam             6
# flour, jam                           6
# bread, cheese, flour, jam            5
# eggs, flour                          5
# bread, cheese, eggs, flour           3
# cheese, flour                        2
# bread, cheese, eggs, flour, jam      2
# cheese, eggs, flour                  1

# %% [markdown]
# ## Problem 2: A Plot of the International Space Station's Location

# %% [markdown]
# We will only be checking the final output of this problem.
#
# ### Context
#
# You are a budding data scientist aiming to try your new tools on real-world data. As a pet project, you have decided that you want to try plotting the latitude and longitude positions of the International Space Station on a chart.
#
# An "application programming interface" (API) is an interface (i.e., a point of connection/use) that a program offers to other pieces of software. APIs are how modern computer programs interact. To massively oversimplify the concept, modern applications send and receive HTTP requests and JSON-formatted data to talk to each other.
#
# We will be using the ISS position data API hosted at http://open-notify.org/Open-Notify-API/ISS-Location-Now/ for this item.
#
# You are expected to read the documentation of this API for this item.

# %% [markdown]
# ### 2.1
#
# Use the `requests` library and the `time` library to collect position data of the ISS at intervals of 10 seconds over the course of 30 minutes by sending GET requests to the ISS API endpoint.
#
# The specifications of this problem are as follows:
# 1. Send a GET request to the ISS API endpoint once every 10 seconds for 30 minutes.
# 2. Each time you send a GET request, append the returned data to a list called `iss_data`.
# 3. Save all the data to a file called `iss-data.json` so that you do not lose it. You may do this every time you get a request if you wish.
# 4. Do not modify the returned data per GET request.
# 5. The final file `iss-data.json` should contain roughly 180 data points.
#
# We will not be strict about the time intervals. We will only look at the chart that you produce from your data.

# %%
# CODE CELL

# CODE START

import time
import json

iss=[]
start=time.time() 
t_end=time.time()+60*30

while time.time()<t_end:
    response=requests.get("http://api.open-notify.org/iss-now.json")
    details=json.loads((response.content).decode('utf-8'))
    iss.append(details)
    time.sleep(10)
    
with open('iss-data.json','w') as f:
    json.dump(iss, f,indent=4)

# CODE END
iss
#references
#https://www.kite.com/python/answers/how-to-create-a-timed-loop-in-python
#https://stackoverflow.com/questions/24374620/python-loop-to-run-for-certain-amount-of-seconds
#https://www.dataquest.io/blog/python-api-tutorial/
#https://docs.python.org/3/howto/unicode.html
#https://www.geeksforgeeks.org/response-content-python-requests/
# Out:
# [{'message': 'success',
#   'iss_position': {'longitude': '-143.9463', 'latitude': '-37.2108'},
#   'timestamp': 1628241656},
#  {'message': 'success',
#   'iss_position': {'longitude': '-143.3230', 'latitude': '-37.6340'},
#   'timestamp': 1628241667},
#  {'message': 'success',
#   'iss_position': {'longitude': '-142.6921', 'latitude': '-38.0533'},
#   'timestamp': 1628241677},
#  {'message': 'success',
#   'iss_position': {'longitude': '-142.0534', 'latitude': '-38.4687'},
#   'timestamp': 1628241688},
#  {'message': 'success',
#   'iss_position': {'longitude': '-141.4069', 'latitude': '-38.8801'},
#   'timestamp': 1628241698},
#  {'message': 'success',
#   'iss_position': {'longitude': '-140.7837', 'latitude': '-39.2680'},
#   'timestamp': 1628241708},
#  {'message': 'success',
#   'iss_position': {'longitude': '-140.1215', 'latitude': '-39.6712'},
#   'timestamp': 1628241719},
#  {'message': 'success',
#   'iss_position': {'longitude': '-139.4511', 'latitude': '-40.0701'},
#   'timestamp': 1628241729},
#  {'message': 'success',
#   'iss_position': {'longitude': '-138.7723', 'latitude': '-40.4645'},
#   'timestamp': 1628241740},
#  {'message': 'success',
#   'iss_position': {'longitude': '-138.0849', 'latitude': '-40.8544'},
#   'timestamp': 1628241750},
#  {'message': 'success',
#   'iss_position': {'longitude': '-137.3889', 'latitude': '-41.2396'},
#   'timestamp': 1628241761},
#  {'message': 'success',
#   'iss_position': {'longitude': '-136.6842', 'latitude': '-41.6200'},
#   'timestamp': 1628241771},
#  {'message': 'success',
#   'iss_position': {'longitude': '-136.0048', 'latitude': '-41.9777'},
#   'timestamp': 1628241781},
#  {'message': 'success',
#   'iss_position': {'longitude': '-135.2829', 'latitude': '-42.3483'},
#   'timestamp': 1628241792},
#  {'message': 'success',
#   'iss_position': {'longitude': '-134.5517', 'latitude': '-42.7139'},
#   'timestamp': 1628241802},
#  {'message': 'success',
#   'iss_position': {'longitude': '-133.8115', 'latitude': '-43.0741'},
#   'timestamp': 1628241813},
#  {'message': 'success',
#   'iss_position': {'longitude': '-133.0621', 'latitude': '-43.4288'},
#   'timestamp': 1628241823},
#  {'message': 'success',
#   'iss_position': {'longitude': '-132.3035', 'latitude': '-43.7780'},
#   'timestamp': 1628241834},
#  {'message': 'success',
#   'iss_position': {'longitude': '-131.5723', 'latitude': '-44.1053'},
#   'timestamp': 1628241844},
#  {'message': 'success',
#   'iss_position': {'longitude': '-130.7953', 'latitude': '-44.4433'},
#   'timestamp': 1628241854},
#  {'message': 'success',
#   'iss_position': {'longitude': '-130.0088', 'latitude': '-44.7753'},
#   'timestamp': 1628241865},
#  {'message': 'success',
#   'iss_position': {'longitude': '-129.2128', 'latitude': '-45.1013'},
#   'timestamp': 1628241876},
#  {'message': 'success',
#   'iss_position': {'longitude': '-128.4074', 'latitude': '-45.4209'},
#   'timestamp': 1628241886},
#  {'message': 'success',
#   'iss_position': {'longitude': '-127.5924', 'latitude': '-45.7342'},
#   'timestamp': 1628241897},
#  {'message': 'success',
#   'iss_position': {'longitude': '-126.7676', 'latitude': '-46.0410'},
#   'timestamp': 1628241907},
#  {'message': 'success',
#   'iss_position': {'longitude': '-125.9732', 'latitude': '-46.3270'},
#   'timestamp': 1628241917},
#  {'message': 'success',
#   'iss_position': {'longitude': '-125.1298', 'latitude': '-46.6206'},
#   'timestamp': 1628241928},
#  {'message': 'success',
#   'iss_position': {'longitude': '-124.2768', 'latitude': '-46.9073'},
#   'timestamp': 1628241938},
#  {'message': 'success',
#   'iss_position': {'longitude': '-123.4143', 'latitude': '-47.1869'},
#   'timestamp': 1628241949},
#  {'message': 'success',
#   'iss_position': {'longitude': '-122.5424', 'latitude': '-47.4592'},
#   'timestamp': 1628241959},
#  {'message': 'success',
#   'iss_position': {'longitude': '-121.6612', 'latitude': '-47.7241'},
#   'timestamp': 1628241970},
#  {'message': 'success',
#   'iss_position': {'longitude': '-120.8132', 'latitude': '-47.9695'},
#   'timestamp': 1628241980},
#  {'message': 'success',
#   'iss_position': {'longitude': '-119.9138', 'latitude': '-48.2196'},
#   'timestamp': 1628241990},
#  {'message': 'success',
#   'iss_position': {'longitude': '-119.0053', 'latitude': '-48.4619'},
#   'timestamp': 1628242001},
#  {'message': 'success',
#   'iss_position': {'longitude': '-118.0878', 'latitude': '-48.6963'},
#   'timestamp': 1628242011},
#  {'message': 'success',
#   'iss_position': {'longitude': '-117.1615', 'latitude': '-48.9226'},
#   'timestamp': 1628242022},
#  {'message': 'success',
#   'iss_position': {'longitude': '-116.2265', 'latitude': '-49.1407'},
#   'timestamp': 1628242032},
#  {'message': 'success',
#   'iss_position': {'longitude': '-115.2830', 'latitude': '-49.3504'},
#   'timestamp': 1628242043},
#  {'message': 'success',
#   'iss_position': {'longitude': '-114.3768', 'latitude': '-49.5422'},
#   'timestamp': 1628242053},
#  {'message': 'success',
#   'iss_position': {'longitude': '-113.4174', 'latitude': '-49.7352'},
#   'timestamp': 1628242063},
#  {'message': 'success',
#   'iss_position': {'longitude': '-112.4501', 'latitude': '-49.9195'},
#   'timestamp': 1628242074},
#  {'message': 'success',
#   'iss_position': {'longitude': '-111.4752', 'latitude': '-50.0949'},
#   'timestamp': 1628242084},
#  {'message': 'success',
#   'iss_position': {'longitude': '-110.4931', 'latitude': '-50.2613'},
#   'timestamp': 1628242095},
#  {'message': 'success',
#   'iss_position': {'longitude': '-109.5039', 'latitude': '-50.4186'},
#   'timestamp': 1628242105},
#  {'message': 'success',
#   'iss_position': {'longitude': '-108.5081', 'latitude': '-50.5666'},
#   'timestamp': 1628242116},
#  {'message': 'success',
#   'iss_position': {'longitude': '-107.5538', 'latitude': '-50.6990'},
#   'timestamp': 1628242126},
#  {'message': 'success',
#   'iss_position': {'longitude': '-106.5459', 'latitude': '-50.8288'},
#   'timestamp': 1628242136},
#  {'message': 'success',
#   'iss_position': {'longitude': '-105.5323', 'latitude': '-50.9490'},
#   'timestamp': 1628242147},
#  {'message': 'success',
#   'iss_position': {'longitude': '-104.5135', 'latitude': '-51.0597'},
#   'timestamp': 1628242158},
#  {'message': 'success',
#   'iss_position': {'longitude': '-103.4897', 'latitude': '-51.1606'},
#   'timestamp': 1628242168},
#  {'message': 'success',
#   'iss_position': {'longitude': '-102.4616', 'latitude': '-51.2518'},
#   'timestamp': 1628242179},
#  {'message': 'success',
#   'iss_position': {'longitude': '-101.4295', 'latitude': '-51.3331'},
#   'timestamp': 1628242189},
#  {'message': 'success',
#   'iss_position': {'longitude': '-100.4432', 'latitude': '-51.4014'},
#   'timestamp': 1628242199},
#  {'message': 'success',
#   'iss_position': {'longitude': '-99.4041', 'latitude': '-51.4634'},
#   'timestamp': 1628242210},
#  {'message': 'success',
#   'iss_position': {'longitude': '-98.3626', 'latitude': '-51.5153'},
#   'timestamp': 1628242220},
#  {'message': 'success',
#   'iss_position': {'longitude': '-97.3189', 'latitude': '-51.5572'},
#   'timestamp': 1628242231},
#  {'message': 'success',
#   'iss_position': {'longitude': '-96.2734', 'latitude': '-51.5890'},
#   'timestamp': 1628242241},
#  {'message': 'success',
#   'iss_position': {'longitude': '-95.2266', 'latitude': '-51.6107'},
#   'timestamp': 1628242252},
#  {'message': 'success',
#   'iss_position': {'longitude': '-94.2288', 'latitude': '-51.6220'},
#   'timestamp': 1628242262},
#  {'message': 'success',
#   'iss_position': {'longitude': '-93.1809', 'latitude': '-51.6239'},
#   'timestamp': 1628242272},
#  {'message': 'success',
#   'iss_position': {'longitude': '-92.1333', 'latitude': '-51.6157'},
#   'timestamp': 1628242283},
#  {'message': 'success',
#   'iss_position': {'longitude': '-91.0864', 'latitude': '-51.5973'},
#   'timestamp': 1628242293},
#  {'message': 'success',
#   'iss_position': {'longitude': '-90.0406', 'latitude': '-51.5689'},
#   'timestamp': 1628242304},
#  {'message': 'success',
#   'iss_position': {'longitude': '-88.9963', 'latitude': '-51.5303'},
#   'timestamp': 1628242314},
#  {'message': 'success',
#   'iss_position': {'longitude': '-87.9540', 'latitude': '-51.4817'},
#   'timestamp': 1628242325},
#  {'message': 'success',
#   'iss_position': {'longitude': '-86.9638', 'latitude': '-51.4261'},
#   'timestamp': 1628242335},
#  {'message': 'success',
#   'iss_position': {'longitude': '-85.9269', 'latitude': '-51.3580'},
#   'timestamp': 1628242345},
#  {'message': 'success',
#   'iss_position': {'longitude': '-84.8935', 'latitude': '-51.2799'},
#   'timestamp': 1628242356},
#  {'message': 'success',
#   'iss_position': {'longitude': '-83.8641', 'latitude': '-51.1920'},
#   'timestamp': 1628242366},
#  {'message': 'success',
#   'iss_position': {'longitude': '-82.8389', 'latitude': '-51.0943'},
#   'timestamp': 1628242377},
#  {'message': 'success',
#   'iss_position': {'longitude': '-81.8184', 'latitude': '-50.9869'},
#   'timestamp': 1628242387},
#  {'message': 'success',
#   'iss_position': {'longitude': '-80.8514', 'latitude': '-50.8756'},
#   'timestamp': 1628242397},
#  {'message': 'success',
#   'iss_position': {'longitude': '-79.8414', 'latitude': '-50.7494'},
#   'timestamp': 1628242408},
#  {'message': 'success',
#   'iss_position': {'longitude': '-78.8370', 'latitude': '-50.6138'},
#   'timestamp': 1628242419},
#  {'message': 'success',
#   'iss_position': {'longitude': '-77.8390', 'latitude': '-50.4688'},
#   'timestamp': 1628242429},
#  {'message': 'success',
#   'iss_position': {'longitude': '-76.8477', 'latitude': '-50.3146'},
#   'timestamp': 1628242440},
#  {'message': 'success',
#   'iss_position': {'longitude': '-75.8632', 'latitude': '-50.1512'},
#   'timestamp': 1628242450},
#  {'message': 'success',
#   'iss_position': {'longitude': '-74.8858', 'latitude': '-49.9788'},
#   'timestamp': 1628242461},
#  {'message': 'success',
#   'iss_position': {'longitude': '-73.9620', 'latitude': '-49.8063'},
#   'timestamp': 1628242471},
#  {'message': 'success',
#   'iss_position': {'longitude': '-72.9996', 'latitude': '-49.6166'},
#   'timestamp': 1628242481},
#  {'message': 'success',
#   'iss_position': {'longitude': '-72.0451', 'latitude': '-49.4182'},
#   'timestamp': 1628242492},
#  {'message': 'success',
#   'iss_position': {'longitude': '-71.0988', 'latitude': '-49.2113'},
#   'timestamp': 1628242502},
#  {'message': 'success',
#   'iss_position': {'longitude': '-70.1605', 'latitude': '-48.9959'},
#   'timestamp': 1628242513},
#  {'message': 'success',
#   'iss_position': {'longitude': '-69.2313', 'latitude': '-48.7723'},
#   'timestamp': 1628242523},
#  {'message': 'success',
#   'iss_position': {'longitude': '-68.3110', 'latitude': '-48.5406'},
#   'timestamp': 1628242534},
#  {'message': 'success',
#   'iss_position': {'longitude': '-67.4426', 'latitude': '-48.3125'},
#   'timestamp': 1628242544},
#  {'message': 'success',
#   'iss_position': {'longitude': '-66.5398', 'latitude': '-48.0654'},
#   'timestamp': 1628242554},
#  {'message': 'success',
#   'iss_position': {'longitude': '-65.6462', 'latitude': '-47.8105'},
#   'timestamp': 1628242565},
#  {'message': 'success',
#   'iss_position': {'longitude': '-64.7617', 'latitude': '-47.5480'},
#   'timestamp': 1628242575},
#  {'message': 'success',
#   'iss_position': {'longitude': '-63.8867', 'latitude': '-47.2781'},
#   'timestamp': 1628242586},
#  {'message': 'success',
#   'iss_position': {'longitude': '-63.0212', 'latitude': '-47.0009'},
#   'timestamp': 1628242596},
#  {'message': 'success',
#   'iss_position': {'longitude': '-62.1651', 'latitude': '-46.7166'},
#   'timestamp': 1628242607},
#  {'message': 'success',
#   'iss_position': {'longitude': '-61.3587', 'latitude': '-46.4393'},
#   'timestamp': 1628242617},
#  {'message': 'success',
#   'iss_position': {'longitude': '-60.5213', 'latitude': '-46.1415'},
#   'timestamp': 1628242627},
#  {'message': 'success',
#   'iss_position': {'longitude': '-59.6936', 'latitude': '-45.8370'},
#   'timestamp': 1628242638},
#  {'message': 'success',
#   'iss_position': {'longitude': '-58.8755', 'latitude': '-45.5259'},
#   'timestamp': 1628242648},
#  {'message': 'success',
#   'iss_position': {'longitude': '-58.0669', 'latitude': '-45.2083'},
#   'timestamp': 1628242659},
#  {'message': 'success',
#   'iss_position': {'longitude': '-57.2679', 'latitude': '-44.8845'},
#   'timestamp': 1628242669},
#  {'message': 'success',
#   'iss_position': {'longitude': '-56.4785', 'latitude': '-44.5546'},
#   'timestamp': 1628242680},
#  {'message': 'success',
#   'iss_position': {'longitude': '-55.7353', 'latitude': '-44.2348'},
#   'timestamp': 1628242690},
#  {'message': 'success',
#   'iss_position': {'longitude': '-54.9643', 'latitude': '-43.8933'},
#   'timestamp': 1628242701},
#  {'message': 'success',
#   'iss_position': {'longitude': '-54.2025', 'latitude': '-43.5459'},
#   'timestamp': 1628242711},
#  {'message': 'success',
#   'iss_position': {'longitude': '-53.4502', 'latitude': '-43.1931'},
#   'timestamp': 1628242722},
#  {'message': 'success',
#   'iss_position': {'longitude': '-52.7071', 'latitude': '-42.8347'},
#   'timestamp': 1628242732},
#  {'message': 'success',
#   'iss_position': {'longitude': '-51.9730', 'latitude': '-42.4710'},
#   'timestamp': 1628242743},
#  {'message': 'success',
#   'iss_position': {'longitude': '-51.2824', 'latitude': '-42.1198'},
#   'timestamp': 1628242753},
#  {'message': 'success',
#   'iss_position': {'longitude': '-50.5659', 'latitude': '-41.7459'},
#   'timestamp': 1628242763},
#  {'message': 'success',
#   'iss_position': {'longitude': '-49.8581', 'latitude': '-41.3671'},
#   'timestamp': 1628242774},
#  {'message': 'success',
#   'iss_position': {'longitude': '-49.1593', 'latitude': '-40.9836'},
#   'timestamp': 1628242784},
#  {'message': 'success',
#   'iss_position': {'longitude': '-48.4691', 'latitude': '-40.5953'},
#   'timestamp': 1628242795},
#  {'message': 'success',
#   'iss_position': {'longitude': '-47.7874', 'latitude': '-40.2023'},
#   'timestamp': 1628242805},
#  {'message': 'success',
#   'iss_position': {'longitude': '-47.1460', 'latitude': '-39.8239'},
#   'timestamp': 1628242815},
#  {'message': 'success',
#   'iss_position': {'longitude': '-46.4806', 'latitude': '-39.4223'},
#   'timestamp': 1628242826},
#  {'message': 'success',
#   'iss_position': {'longitude': '-45.8233', 'latitude': '-39.0164'},
#   'timestamp': 1628242836},
#  {'message': 'success',
#   'iss_position': {'longitude': '-45.1742', 'latitude': '-38.6064'},
#   'timestamp': 1628242847},
#  {'message': 'success',
#   'iss_position': {'longitude': '-44.5329', 'latitude': '-38.1923'},
#   'timestamp': 1628242857},
#  {'message': 'success',
#   'iss_position': {'longitude': '-43.8994', 'latitude': '-37.7743'},
#   'timestamp': 1628242868},
#  {'message': 'success',
#   'iss_position': {'longitude': '-43.3033', 'latitude': '-37.3726'},
#   'timestamp': 1628242878},
#  {'message': 'success',
#   'iss_position': {'longitude': '-42.6846', 'latitude': '-36.9472'},
#   'timestamp': 1628242888},
#  {'message': 'success',
#   'iss_position': {'longitude': '-42.0732', 'latitude': '-36.5180'},
#   'timestamp': 1628242899},
#  {'message': 'success',
#   'iss_position': {'longitude': '-41.4693', 'latitude': '-36.0854'},
#   'timestamp': 1628242909},
#  {'message': 'success',
#   'iss_position': {'longitude': '-40.8723', 'latitude': '-35.6493'},
#   'timestamp': 1628242920},
#  {'message': 'success',
#   'iss_position': {'longitude': '-40.2823', 'latitude': '-35.2097'},
#   'timestamp': 1628242930},
#  {'message': 'success',
#   'iss_position': {'longitude': '-39.6992', 'latitude': '-34.7669'},
#   'timestamp': 1628242941},
#  {'message': 'success',
#   'iss_position': {'longitude': '-39.1502', 'latitude': '-34.3423'},
#   'timestamp': 1628242951},
#  {'message': 'success',
#   'iss_position': {'longitude': '-38.5802', 'latitude': '-33.8935'},
#   'timestamp': 1628242961},
#  {'message': 'success',
#   'iss_position': {'longitude': '-38.0166', 'latitude': '-33.4415'},
#   'timestamp': 1628242972},
#  {'message': 'success',
#   'iss_position': {'longitude': '-37.4593', 'latitude': '-32.9867'},
#   'timestamp': 1628242983},
#  {'message': 'success',
#   'iss_position': {'longitude': '-36.9081', 'latitude': '-32.5289'},
#   'timestamp': 1628242993},
#  {'message': 'success',
#   'iss_position': {'longitude': '-36.3629', 'latitude': '-32.0682'},
#   'timestamp': 1628243004},
#  {'message': 'success',
#   'iss_position': {'longitude': '-35.8493', 'latitude': '-31.6271'},
#   'timestamp': 1628243014},
#  {'message': 'success',
#   'iss_position': {'longitude': '-35.3156', 'latitude': '-31.1614'},
#   'timestamp': 1628243024},
#  {'message': 'success',
#   'iss_position': {'longitude': '-34.7877', 'latitude': '-30.6931'},
#   'timestamp': 1628243035},
#  {'message': 'success',
#   'iss_position': {'longitude': '-34.2653', 'latitude': '-30.2224'},
#   'timestamp': 1628243045},
#  {'message': 'success',
#   'iss_position': {'longitude': '-33.7481', 'latitude': '-29.7490'},
#   'timestamp': 1628243056},
#  {'message': 'success',
#   'iss_position': {'longitude': '-33.2363', 'latitude': '-29.2733'},
#   'timestamp': 1628243066},
#  {'message': 'success',
#   'iss_position': {'longitude': '-32.7296', 'latitude': '-28.7954'},
#   'timestamp': 1628243077},
#  {'message': 'success',
#   'iss_position': {'longitude': '-32.2518', 'latitude': '-28.3382'},
#   'timestamp': 1628243087},
#  {'message': 'success',
#   'iss_position': {'longitude': '-31.7550', 'latitude': '-27.8561'},
#   'timestamp': 1628243097},
#  {'message': 'success',
#   'iss_position': {'longitude': '-31.2628', 'latitude': '-27.3717'},
#   'timestamp': 1628243108},
#  {'message': 'success',
#   'iss_position': {'longitude': '-30.7754', 'latitude': '-26.8854'},
#   'timestamp': 1628243118},
#  {'message': 'success',
#   'iss_position': {'longitude': '-30.2924', 'latitude': '-26.3970'},
#   'timestamp': 1628243129},
#  {'message': 'success',
#   'iss_position': {'longitude': '-29.8139', 'latitude': '-25.9067'},
#   'timestamp': 1628243139},
#  {'message': 'success',
#   'iss_position': {'longitude': '-29.3624', 'latitude': '-25.4382'},
#   'timestamp': 1628243149},
#  {'message': 'success',
#   'iss_position': {'longitude': '-28.8477', 'latitude': '-24.8972'},
#   'timestamp': 1628243161},
#  {'message': 'success',
#   'iss_position': {'longitude': '-28.3821', 'latitude': '-24.4014'},
#   'timestamp': 1628243171},
#  {'message': 'success',
#   'iss_position': {'longitude': '-27.9205', 'latitude': '-23.9040'},
#   'timestamp': 1628243182},
#  {'message': 'success',
#   'iss_position': {'longitude': '-27.4628', 'latitude': '-23.4049'},
#   'timestamp': 1628243192},
#  {'message': 'success',
#   'iss_position': {'longitude': '-27.0088', 'latitude': '-22.9041'},
#   'timestamp': 1628243203},
#  {'message': 'success',
#   'iss_position': {'longitude': '-26.5585', 'latitude': '-22.4018'},
#   'timestamp': 1628243213},
#  {'message': 'success',
#   'iss_position': {'longitude': '-26.1330', 'latitude': '-21.9221'},
#   'timestamp': 1628243223},
#  {'message': 'success',
#   'iss_position': {'longitude': '-25.6896', 'latitude': '-21.4170'},
#   'timestamp': 1628243234},
#  {'message': 'success',
#   'iss_position': {'longitude': '-25.2495', 'latitude': '-20.9104'},
#   'timestamp': 1628243245},
#  {'message': 'success',
#   'iss_position': {'longitude': '-24.8127', 'latitude': '-20.4024'},
#   'timestamp': 1628243255},
#  {'message': 'success',
#   'iss_position': {'longitude': '-24.3790', 'latitude': '-19.8931'},
#   'timestamp': 1628243266},
#  {'message': 'success',
#   'iss_position': {'longitude': '-23.9484', 'latitude': '-19.3826'},
#   'timestamp': 1628243276},
#  {'message': 'success',
#   'iss_position': {'longitude': '-23.5207', 'latitude': '-18.8707'},
#   'timestamp': 1628243287},
#  {'message': 'success',
#   'iss_position': {'longitude': '-23.1161', 'latitude': '-18.3822'},
#   'timestamp': 1628243297},
#  {'message': 'success',
#   'iss_position': {'longitude': '-22.6940', 'latitude': '-17.8681'},
#   'timestamp': 1628243307},
#  {'message': 'success',
#   'iss_position': {'longitude': '-22.2745', 'latitude': '-17.3529'},
#   'timestamp': 1628243318},
#  {'message': 'success',
#   'iss_position': {'longitude': '-21.8577', 'latitude': '-16.8366'},
#   'timestamp': 1628243328},
#  {'message': 'success',
#   'iss_position': {'longitude': '-21.4434', 'latitude': '-16.3194'},
#   'timestamp': 1628243339},
#  {'message': 'success',
#   'iss_position': {'longitude': '-21.0314', 'latitude': '-15.8010'},
#   'timestamp': 1628243349},
#  {'message': 'success',
#   'iss_position': {'longitude': '-20.6219', 'latitude': '-15.2818'},
#   'timestamp': 1628243360},
#  {'message': 'success',
#   'iss_position': {'longitude': '-20.2339', 'latitude': '-14.7865'},
#   'timestamp': 1628243370},
#  {'message': 'success',
#   'iss_position': {'longitude': '-19.8286', 'latitude': '-14.2655'},
#   'timestamp': 1628243380},
#  {'message': 'success',
#   'iss_position': {'longitude': '-19.4253', 'latitude': '-13.7436'},
#   'timestamp': 1628243391},
#  {'message': 'success',
#   'iss_position': {'longitude': '-19.0048', 'latitude': '-13.1958'},
#   'timestamp': 1628243402},
#  {'message': 'success',
#   'iss_position': {'longitude': '-18.6053', 'latitude': '-12.6719'},
#   'timestamp': 1628243412},
#  {'message': 'success',
#   'iss_position': {'longitude': '-18.2078', 'latitude': '-12.1477'},
#   'timestamp': 1628243423},
#  {'message': 'success',
#   'iss_position': {'longitude': '-17.8121', 'latitude': '-11.6228'},
#   'timestamp': 1628243433},
#  {'message': 'success',
#   'iss_position': {'longitude': '-17.4368', 'latitude': '-11.1222'},
#   'timestamp': 1628243443},
#  {'message': 'success',
#   'iss_position': {'longitude': '-17.0442', 'latitude': '-10.5960'},
#   'timestamp': 1628243454}]

# %% [markdown]
# ### 2.2
#
# Using the data you gathered and stored in `iss-data.json`, make a `matplotlib` plot of the location data.
#
# The specifications of this problem are as follows:
# 1. Use the longitude and latitude data contained in `iss-data.json` as your data.
# 2. Plot this data on a `matplotlib` plot that appropriately visualizes the data. It is up to you what specific plot you want to use as long as we, the human readers of your report, understand the message of your plot.
# 3. Use latitude as the X axis and longitude as the Y axis.
# 4. VERY IMPORTANT: Make sure that the chart displays in your Jupyter notebook before you submit.
#
# We will only check the chart. We do not care how you make it display as long as you follow the specifications.

# %%
# CODE CELL

# CODE START

df=pd.read_json('iss-data.json')

longitude=[]
for i in range(len(df)):
    longitude+=[float(df['iss_position'][i]['longitude'])]

latitude=[]
for i in range(len(df)):
    latitude+=[float(df['iss_position'][i]['latitude'])]


# %matplotlib inline

plt.figure(figsize=(10, 10), dpi=100)
plt.plot(latitude, longitude, 'b')
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.title('ISS Location Data')
plt.show()

#references
#https://stackoverflow.com/questions/25888396/how-to-get-latitude-longitude-with-python
#https://ipython.readthedocs.io/en/stable/interactive/plotting.html
